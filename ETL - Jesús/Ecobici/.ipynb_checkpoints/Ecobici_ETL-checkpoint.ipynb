# %%
import numpy as np
import pandas as pd
import requests
from io import StringIO

# %%
#Usar requests
#response = requests.get("https://ecobici.cdmx.gob.mx/wp-content/uploads/2025/02/2025-01.csv")
#df = pd.read_csv(StringIO(response.text))

# %%
##leerdirectamente desde URL
#df = pd.read_csv("https://ecobici.cdmx.gob.mx/wp-content/uploads/2025/02/2025-01.csv")
df = pd.read_csv('2025-01.csv')

# %% [markdown]
# **Calculo de moda, media y mediana**

# %%
df.mode()
# Out:
#   Genero_Usuario  Edad_Usuario     Bici Ciclo_Estacion_Retiro Fecha_Retiro  \
# 0              M          30.0  8537367               271-272   29/01/2025
#
#   Hora_Retiro Ciclo_EstacionArribo Fecha_Arribo Hora_Arribo
# 0    18:05:49              271-272   29/01/2025    18:34:56

# %%
df.mean(numeric_only=True)
# Out:
# Edad_Usuario    3.400352e+01
# Bici            5.456875e+06
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Edad_Usuario         32.0
# Bici            5452651.0
# dtype: float64

# %%
df.head(10)
# Out:
#   Genero_Usuario  Edad_Usuario     Bici Ciclo_Estacion_Retiro Fecha_Retiro  \
# 0              M          26.0  5180930                   568   31/12/2024
# 1              F          54.0  3653953                   283   31/12/2024
# 2              M          38.0  7511322                   034   31/12/2024
# 3              M          41.0  3804572                   258   31/12/2024
# 4              M          35.0  3848405                   043   31/12/2024
# 5              M          24.0  7579436                   222   31/12/2024
# 6              M          31.0  7161920                   034   31/12/2024
# 7              M          22.0  7220593                   254   31/12/2024
# 8              M          29.0  4031258                   560   31/12/2024
# 9              F          24.0  6463376                   560   31/12/2024
#
#   Hora_Retiro Ciclo_EstacionArribo Fecha_Arribo Hora_Arribo
# 0    23:57:02                  572   01/01/2025    00:00:03
# ...

# %%
print("El número total de registros es:",len(df))
# Out:
# El número total de registros es: 1809775

# %%
print("Tamaño del dataset")
print(df.shape)
# Out:
# Tamaño del dataset
# (1809775, 9)

# %%
df.isnull().sum()
# Out:
# Genero_Usuario             1
# Edad_Usuario             147
# Bici                       0
# Ciclo_Estacion_Retiro      0
# Fecha_Retiro               0
# Hora_Retiro                0
# Ciclo_EstacionArribo       0
# Fecha_Arribo               0
# Hora_Arribo                0
# dtype: int64

# %%
df['Hora_Retiro'] = df['Hora_Retiro'].astype(str)
df['Hora_Arribo'] = df['Hora_Arribo'].astype(str)
df['Fecha_Retiro'] = df['Fecha_Retiro'].astype(str)
df['Fecha_Arribo'] = df['Fecha_Arribo'].astype(str)

# %%
df.dtypes
# Out:
# Genero_Usuario            object
# Edad_Usuario             float64
# Bici                       int64
# Ciclo_Estacion_Retiro     object
# Fecha_Retiro              object
# Hora_Retiro               object
# Ciclo_EstacionArribo      object
# Fecha_Arribo              object
# Hora_Arribo               object
# dtype: object

# %%
df['Fecha_Hora_Retiro'] =  df['Fecha_Retiro'] + ' ' + df['Hora_Retiro']
df['Fecha_Hora_Arribo'] =  df['Fecha_Arribo'] + ' ' + df['Hora_Arribo']

# %%
df.head()
# Out:
#   Genero_Usuario  Edad_Usuario     Bici Ciclo_Estacion_Retiro Fecha_Retiro  \
# 0              M          26.0  5180930                   568   31/12/2024
# 1              F          54.0  3653953                   283   31/12/2024
# 2              M          38.0  7511322                   034   31/12/2024
# 3              M          41.0  3804572                   258   31/12/2024
# 4              M          35.0  3848405                   043   31/12/2024
#
#   Hora_Retiro Ciclo_EstacionArribo Fecha_Arribo Hora_Arribo  \
# 0    23:57:02                  572   01/01/2025    00:00:03
# 1    23:51:40                  596   01/01/2025    00:00:41
# 2    23:48:36                  064   01/01/2025    00:00:59
# 3    23:54:11                  023   01/01/2025    00:01:08
# 4    23:35:28                  126   01/01/2025    00:01:17
#
#      Fecha_Hora_Retiro    Fecha_Hora_Arribo
# 0  31/12/2024 23:57:02  01/01/2025 00:00:03
# 1  31/12/2024 23:51:40  01/01/2025 00:00:41
# ...

# %%
df['Fecha_Hora_Retiro'] = pd.to_datetime(df['Fecha_Hora_Retiro'],dayfirst=True)
df['Fecha_Hora_Arribo'] = pd.to_datetime(df['Fecha_Hora_Arribo'],dayfirst=True)

# %%
df.dtypes
# Out:
# Genero_Usuario                   object
# Edad_Usuario                    float64
# Bici                              int64
# Ciclo_Estacion_Retiro            object
# Fecha_Retiro                     object
# Hora_Retiro                      object
# Ciclo_EstacionArribo             object
# Fecha_Arribo                     object
# Hora_Arribo                      object
# Fecha_Hora_Retiro        datetime64[ns]
# Fecha_Hora_Arribo        datetime64[ns]
# dtype: object

# %%
df['duracion'] = df['Fecha_Hora_Arribo'] - df['Fecha_Hora_Retiro']

# %%
#es mas recomendable usar la mediana y no la media
df['Edad_Usuario'] = df['Edad_Usuario'].transform(lambda x: x.fillna(x.median()))

# %%
#df = pd.get_dummies(df, columns=['Genero_Usuario'], prefix=['Genero_Usuario'])

# %%
df.head()
# Out:
#   Genero_Usuario  Edad_Usuario     Bici Ciclo_Estacion_Retiro Fecha_Retiro  \
# 0              M          26.0  5180930                   568   31/12/2024
# 1              F          54.0  3653953                   283   31/12/2024
# 2              M          38.0  7511322                   034   31/12/2024
# 3              M          41.0  3804572                   258   31/12/2024
# 4              M          35.0  3848405                   043   31/12/2024
#
#   Hora_Retiro Ciclo_EstacionArribo Fecha_Arribo Hora_Arribo  \
# 0    23:57:02                  572   01/01/2025    00:00:03
# 1    23:51:40                  596   01/01/2025    00:00:41
# 2    23:48:36                  064   01/01/2025    00:00:59
# 3    23:54:11                  023   01/01/2025    00:01:08
# 4    23:35:28                  126   01/01/2025    00:01:17
#
#     Fecha_Hora_Retiro   Fecha_Hora_Arribo        duracion
# 0 2024-12-31 23:57:02 2025-01-01 00:00:03 0 days 00:03:01
# ...

# %%
valores_con_guion = df[df['Ciclo_EstacionArribo'].str.contains('-', case=False, na=False)]['Ciclo_EstacionArribo'].unique()

# %%
valores_con_guion
# Out:
# array(['235-236', '237-238', '107-108', '445-446', '390-391', '192-193',
#        '158-159', '271-272', '266-267', '264-275', '273-274', '268-269'],
#       dtype=object)

# %%
# Crear diccionario de reemplazos
replacement_dict = {
    '235-236': 235,
    '237-238': 237,
    '107-108': 107,
    '445-446': 445,
    '390-391': 390,
    '192-193': 192,
    '158-159': 158,
    '271-272': 271,
    '266-267': 266,
    '264-275': 264,
    '273-274': 273,
    '268-269': 268
}

# Aplicar reemplazo a ambas columnas
df['Ciclo_Estacion_Retiro'] = df['Ciclo_Estacion_Retiro'].replace(replacement_dict)
df['Ciclo_EstacionArribo'] = df['Ciclo_EstacionArribo'].replace(replacement_dict)

# %%
#alternativa en otro dataframe
#df_genero = pd.get_dummies(df_copy[['Genero_Usuario']])

# %%
df.dtypes
# Out:
# Genero_Usuario                    object
# Edad_Usuario                     float64
# Bici                               int64
# Ciclo_Estacion_Retiro             object
# Fecha_Retiro                      object
# Hora_Retiro                       object
# Ciclo_EstacionArribo              object
# Fecha_Arribo                      object
# Hora_Arribo                       object
# Fecha_Hora_Retiro         datetime64[ns]
# Fecha_Hora_Arribo         datetime64[ns]
# duracion                 timedelta64[ns]
# dtype: object

# %%
df['Fecha_Retiro'] = pd.to_datetime(df['Fecha_Retiro'],dayfirst=True)
df['Fecha_Arribo'] = pd.to_datetime(df['Fecha_Arribo'],dayfirst=True)

# %%
df1 = df['Fecha_Retiro'].dt.date.value_counts().sort_index().reset_index()
df1.columns = ['Fecha_Retiro','Count']
df1.head(10)
# Out:
#   Fecha_Retiro  Count
# 0   2023-02-04      1
# 1   2024-08-10      1
# 2   2024-11-25      1
# 3   2024-12-18      1
# 4   2024-12-23      1
# 5   2024-12-28      1
# 6   2024-12-29      1
# 7   2024-12-31    102
# 8   2025-01-01  16643
# 9   2025-01-02  45177

# %%
#label encoding
#assings integers (red=1, blue=2, green=3)
#crea una importancia no real
#mejor one-hot-encoding

# %%
#Crear categoria  "Viaje corto, entre semana o fin de semana"
from datetime import timedelta
def trip_duration(duration):
    if duration <= timedelta(minutes=10):
        return "Viaje corto"
    elif duration > timedelta(minutes=10) and duration <= timedelta(minutes=45):
        return "Viaje regular"
    elif duration > timedelta(minutes=45):
        return "Viaje largo"

# %%
df['tipo_viaje'] = df['duracion'].apply(trip_duration)

# %%
df['tipo_viaje'].value_counts()
# Out:
# tipo_viaje
# Viaje regular    1041519
# Viaje corto       745545
# Viaje largo        22711
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Genero_Usuario                    object
# Edad_Usuario                     float64
# Bici                               int64
# Ciclo_Estacion_Retiro             object
# Fecha_Retiro              datetime64[ns]
# Hora_Retiro                       object
# Ciclo_EstacionArribo              object
# Fecha_Arribo              datetime64[ns]
# Hora_Arribo                       object
# Fecha_Hora_Retiro         datetime64[ns]
# Fecha_Hora_Arribo         datetime64[ns]
# duracion                 timedelta64[ns]
# tipo_viaje                        object
# dtype: object

# %%
df = pd.get_dummies(df, columns=['Genero_Usuario'])

# %%
#Get date from date
df['DiaSemana'] = df['Fecha_Hora_Retiro'].dt.day_name() # or .dt.weekday
df.head()
# Out:
#    Edad_Usuario     Bici Ciclo_Estacion_Retiro Fecha_Retiro Hora_Retiro  \
# 0          26.0  5180930                   568   2024-12-31    23:57:02
# 1          54.0  3653953                   283   2024-12-31    23:51:40
# 2          38.0  7511322                   034   2024-12-31    23:48:36
# 3          41.0  3804572                   258   2024-12-31    23:54:11
# 4          35.0  3848405                   043   2024-12-31    23:35:28
#
#   Ciclo_EstacionArribo Fecha_Arribo Hora_Arribo   Fecha_Hora_Retiro  \
# 0                  572   2025-01-01    00:00:03 2024-12-31 23:57:02
# 1                  596   2025-01-01    00:00:41 2024-12-31 23:51:40
# 2                  064   2025-01-01    00:00:59 2024-12-31 23:48:36
# 3                  023   2025-01-01    00:01:08 2024-12-31 23:54:11
# 4                  126   2025-01-01    00:01:17 2024-12-31 23:35:28
#
#     Fecha_Hora_Arribo        duracion     tipo_viaje  Genero_Usuario_?  \
# ...

# %%
df['DiaSemana'].value_counts()
# Out:
# DiaSemana
# Thursday     329464
# Friday       314452
# Wednesday    302019
# Tuesday      279037
# Monday       261368
# Saturday     164370
# Sunday       159065
# Name: count, dtype: int64

# %%
print("Tamaño del dataset")
print(df.shape)
# Out:
# Tamaño del dataset
# (1809775, 17)

# %%
df['Ciclo_EstacionArribo'].isnull().sum()
# Out:
# 0

# %%
df['duracion'].sort_values(ascending=False)
# Out:
# 1115751   717 days 00:44:58
# 1116290   163 days 21:31:43
# 1455091    62 days 14:53:52
# 1011552    32 days 09:00:11
# 1385051    24 days 16:49:17
#                  ...
# 829615      0 days 00:00:29
# 326233      0 days 00:00:29
# 1584058     0 days 00:00:25
# 364940      0 days 00:00:25
# 396518      0 days 00:00:19
# Name: duracion, Length: 1809775, dtype: timedelta64[ns]

# %%
result = df.groupby(["DiaSemana", "tipo_viaje"]).agg(Count=("Bici", "count")).reset_index()

# %%
result
# Out:
#     DiaSemana     tipo_viaje   Count
# 0      Friday    Viaje corto  130502
# 1      Friday    Viaje largo    3110
# 2      Friday  Viaje regular  180840
# 3      Monday    Viaje corto  111400
# 4      Monday    Viaje largo    2145
# 5      Monday  Viaje regular  147823
# 6    Saturday    Viaje corto   68240
# 7    Saturday    Viaje largo    2524
# 8    Saturday  Viaje regular   93606
# 9      Sunday    Viaje corto   55409
# 10     Sunday    Viaje largo    6517
# 11     Sunday  Viaje regular   97139
# 12   Thursday    Viaje corto  137824
# 13   Thursday    Viaje largo    2999
# 14   Thursday  Viaje regular  188641
# 15    Tuesday    Viaje corto  116619
# 16    Tuesday    Viaje largo    2414
# 17    Tuesday  Viaje regular  160004
# 18  Wednesday    Viaje corto  125551
# 19  Wednesday    Viaje largo    3002
# 20  Wednesday  Viaje regular  173466

# %%
result.sort_values('Count')
# Out:
#     DiaSemana     tipo_viaje   Count
# 4      Monday    Viaje largo    2145
# 16    Tuesday    Viaje largo    2414
# 7    Saturday    Viaje largo    2524
# 13   Thursday    Viaje largo    2999
# 19  Wednesday    Viaje largo    3002
# 1      Friday    Viaje largo    3110
# 10     Sunday    Viaje largo    6517
# 9      Sunday    Viaje corto   55409
# 6    Saturday    Viaje corto   68240
# 8    Saturday  Viaje regular   93606
# 11     Sunday  Viaje regular   97139
# 3      Monday    Viaje corto  111400
# 15    Tuesday    Viaje corto  116619
# 18  Wednesday    Viaje corto  125551
# 0      Friday    Viaje corto  130502
# 12   Thursday    Viaje corto  137824
# 5      Monday  Viaje regular  147823
# 17    Tuesday  Viaje regular  160004
# 20  Wednesday  Viaje regular  173466
# 2      Friday  Viaje regular  180840
# 14   Thursday  Viaje regular  188641

# %%
N_df = df.copy()

# %%
#N_df = pd.get_dummies(N_df, columns=['tipo_viaje'], prefix=['tipo_viaje'])

# %%
N_df.head()
# Out:
#    Edad_Usuario     Bici Ciclo_Estacion_Retiro Fecha_Retiro Hora_Retiro  \
# 0          26.0  5180930                   568   2024-12-31    23:57:02
# 1          54.0  3653953                   283   2024-12-31    23:51:40
# 2          38.0  7511322                   034   2024-12-31    23:48:36
# 3          41.0  3804572                   258   2024-12-31    23:54:11
# 4          35.0  3848405                   043   2024-12-31    23:35:28
#
#   Ciclo_EstacionArribo Fecha_Arribo Hora_Arribo   Fecha_Hora_Retiro  \
# 0                  572   2025-01-01    00:00:03 2024-12-31 23:57:02
# 1                  596   2025-01-01    00:00:41 2024-12-31 23:51:40
# 2                  064   2025-01-01    00:00:59 2024-12-31 23:48:36
# 3                  023   2025-01-01    00:01:08 2024-12-31 23:54:11
# 4                  126   2025-01-01    00:01:17 2024-12-31 23:35:28
#
#     Fecha_Hora_Arribo        duracion     tipo_viaje  Genero_Usuario_?  \
# ...

# %%
N_df = N_df.drop(['Ciclo_EstacionArribo','Ciclo_Estacion_Retiro','Bici','Fecha_Retiro','Hora_Retiro','Fecha_Arribo','Hora_Arribo','Fecha_Hora_Arribo','duracion','tipo_viaje','DiaSemana'], axis=1)

# %%
# Extraer componentes temporales útiles
N_df['hora'] = N_df['Fecha_Hora_Retiro'].dt.hour
N_df['minuto'] = N_df['Fecha_Hora_Retiro'].dt.minute
N_df['dia_del_mes'] = N_df['Fecha_Hora_Retiro'].dt.day
N_df['dia_de_la_semana'] = N_df['Fecha_Hora_Retiro'].dt.dayofweek + 1
N_df['mes'] = N_df['Fecha_Hora_Retiro'].dt.month
N_df['es_fin_de_semana'] = N_df['Fecha_Hora_Retiro'].dt.dayofweek.isin([5, 6]).astype(int)

# %%
N_df = N_df.drop(['Fecha_Hora_Retiro'], axis=1)

# %%
N_df.head()
# Out:
#    Edad_Usuario  Genero_Usuario_?  Genero_Usuario_F  Genero_Usuario_M  \
# 0          26.0             False             False              True
# 1          54.0             False              True             False
# 2          38.0             False             False              True
# 3          41.0             False             False              True
# 4          35.0             False             False              True
#
#    Genero_Usuario_O  hora  minuto  dia_del_mes  dia_de_la_semana  mes  \
# 0             False    23      57           31                 2   12
# 1             False    23      51           31                 2   12
# 2             False    23      48           31                 2   12
# 3             False    23      54           31                 2   12
# 4             False    23      35           31                 2   12
#
#    es_fin_de_semana
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# ...

# %%
#Se podra predecir viajes atipicos
import matplotlib.pyplot as plt
plt.matshow(N_df.corr())
plt.show()

# %%
import pandas as pd
import numpy as np

corr = N_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d558c_row0_col0, #T_d558c_row1_col1, #T_d558c_row2_col2, #T_d558c_row3_col3, #T_d558c_row4_col4, #T_d558c_row5_col5, #T_d558c_row6_col6, #T_d558c_row7_col7, #T_d558c_row8_col8, #T_d558c_row9_col9, #T_d558c_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d558c_row0_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_d558c_row0_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_d558c_row0_col3 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_d558c_row0_col4, #T_d558c_row3_col0, #T_d558c_row8_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_d558c_row0_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_d558c_row0_col6, #T_d558c_row3_col6, #T_d558c_row5_col10, #T_d558c_row7_col0 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# ...

# %%
N_df_y = df[['duracion']]

# %%
N_df_y.head()
# Out:
#          duracion
# 0 0 days 00:03:01
# 1 0 days 00:09:01
# 2 0 days 00:12:23
# 3 0 days 00:06:57
# 4 0 days 00:25:49

# %%
# Convertir la duración a segundos totales
N_df_y = df['duracion'].dt.total_seconds()
# Ver resultado
print(N_df_y.head())
# Out:
# 0     181.0
# 1     541.0
# 2     743.0
# 3     417.0
# 4    1549.0
# Name: duracion, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
import numpy as np

# %%
#No usar
X_train, X_val, y_train, y_val = train_test_split(
    N_df, N_df_y, test_size=0.1, random_state=42
)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# %%
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
X_test_scaled = scaler.transform(X_val)

# %%
y_pred = model.predict(X_test_scaled)

# %%
#Predecir duracion del viaje, predecir viajes atipicos
#CoD R^2; Real-world Utility
#r^2 dice que hay un porcentaje de variabilidad
#Mape real world utility

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_val, y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.0007
