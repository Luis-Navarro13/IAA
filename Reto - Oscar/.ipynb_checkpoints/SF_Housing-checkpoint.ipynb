# %%
# %ls
# Out:
#  El volumen de la unidad C es OS
#  El n£mero de serie del volumen es: 28A3-2B7F
#
#  Directorio de C:\Users\luisn\OneDrive\Documents\GitHub\IAA\Reto - Oscar
#
# 19/08/2025  05:38 p. m.    <DIR>          .
# 19/08/2025  05:13 p. m.    <DIR>          ..
# 19/08/2025  05:16 p. m.    <DIR>          .ipynb_checkpoints
# 19/08/2025  05:38 p. m.            74,926 SF_Housing.ipynb
# 19/08/2025  05:14 p. m.           856,650 sf_housing_dirty.csv
#                2 archivos        931,576 bytes
#                3 dirs  180,050,100,224 bytes libres

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("sf_housing_dirty.csv")

# %%
parsed = pd.to_datetime(df['date'] + ' 2024',errors="coerce")
print("Min date:", parsed.min())
print("Max date:", parsed.max())
# Out:
# Min date: 2024-09-30 00:00:00
# Max date: 2024-10-01 00:00:00

# %%
df.head()
# Out:
#      date                                              title  \
# 0  Oct  1  3D Virtual Tour - 2 BR, 2 BA Condo 966 Sq. Ft....
# 1  Oct  1                           Beautiful house for rent
# 2  Oct  1                  4 BEDROOM APARTMENT IN THE HAIGHT
# 3  Oct  1                  4 BEDROOM APARTMENT IN THE HAIGHT
# 4  Oct  1                    ENJOY GOLDEN GATE PARK EVERYDAY
#
#                                                 link   price  brs   sqft  \
# 0  https://sfbay.craigslist.org/sfc/apa/d/san-fra...  $3,850  2.0  966.0
# 1  https://sfbay.craigslist.org/sfc/apa/d/san-fra...     900  1.0    NaN
# 2  https://sfbay.craigslist.org/sfc/apa/d/san-fra...    4995  4.0    NaN
# 3  https://sfbay.craigslist.org/sfc/apa/d/san-fra...    4995  4.0    NaN
# 4  https://sfbay.craigslist.org/sfc/apa/d/san-fra...    2800  2.0  700.0
#
#                hood bath                                          amenities
# 0       Mission Bay  2Ba        ['condo', 'w/d in unit', 'attached garage']
# 1  portola district  0Ba                                          ['house']
# 2    haight ashbury  2Ba     ['apartment', 'w/d in unit', 'street parking']
# 3    haight ashbury  2Ba     ['apartment', 'w/d in unit', 'street parking']
# 4   USF / panhandle  1Ba  ['apartment', 'laundry in bldg', 'no smoking',...

# %%
df.describe()
# Out:
#                brs          sqft
# count  2476.000000   1461.000000
# mean      1.836430   1202.036277
# std       0.948098   1316.612823
# min       1.000000    110.000000
# 25%       1.000000    650.000000
# 50%       2.000000    902.000000
# 75%       2.000000   1240.000000
# max       7.000000  11020.000000

# %%
df.head()
# Out:
#      date                                              title  \
# 0  Oct  1  3D Virtual Tour - 2 BR, 2 BA Condo 966 Sq. Ft....
# 1  Oct  1                           Beautiful house for rent
# 2  Oct  1                  4 BEDROOM APARTMENT IN THE HAIGHT
# 3  Oct  1                  4 BEDROOM APARTMENT IN THE HAIGHT
# 4  Oct  1                    ENJOY GOLDEN GATE PARK EVERYDAY
#
#                                                 link   price  brs   sqft  \
# 0  https://sfbay.craigslist.org/sfc/apa/d/san-fra...  $3,850  2.0  966.0
# 1  https://sfbay.craigslist.org/sfc/apa/d/san-fra...     900  1.0    NaN
# 2  https://sfbay.craigslist.org/sfc/apa/d/san-fra...    4995  4.0    NaN
# 3  https://sfbay.craigslist.org/sfc/apa/d/san-fra...    4995  4.0    NaN
# 4  https://sfbay.craigslist.org/sfc/apa/d/san-fra...    2800  2.0  700.0
#
#                hood bath                                          amenities
# 0       Mission Bay  2Ba        ['condo', 'w/d in unit', 'attached garage']
# 1  portola district  0Ba                                          ['house']
# 2    haight ashbury  2Ba     ['apartment', 'w/d in unit', 'street parking']
# 3    haight ashbury  2Ba     ['apartment', 'w/d in unit', 'street parking']
# 4   USF / panhandle  1Ba  ['apartment', 'laundry in bldg', 'no smoking',...

# %%
df.dtypes
# Out:
# date          object
# title         object
# link          object
# price         object
# brs          float64
# sqft         float64
# hood          object
# bath          object
# amenities     object
# dtype: object

# %%
if df["price"].dtype == object:
    df["price"] = df["price"].replace('[\$,]','',regex=True).astype(float)

# %%
#alternativa
df['price'] = df['price'].str.replace('$', '')
df['price'] = df['price'].str.replace(',', '')
df['price'] = df['price'].astype(float)

# %%
df.describe()
# Out:
#               price          brs          sqft
# count   3093.000000  2476.000000   1461.000000
# mean    3318.156159     1.836430   1202.036277
# std     1710.975464     0.948098   1316.612823
# min        1.000000     1.000000    110.000000
# 25%     2395.000000     1.000000    650.000000
# 50%     2995.000000     2.000000    902.000000
# 75%     3933.000000     2.000000   1240.000000
# max    29000.000000     7.000000  11020.000000

# %%
df.head()
# Out:
#      date                                              title  \
# 0  Oct  1  3D Virtual Tour - 2 BR, 2 BA Condo 966 Sq. Ft....
# 1  Oct  1                           Beautiful house for rent
# 2  Oct  1                  4 BEDROOM APARTMENT IN THE HAIGHT
# 3  Oct  1                  4 BEDROOM APARTMENT IN THE HAIGHT
# 4  Oct  1                    ENJOY GOLDEN GATE PARK EVERYDAY
#
#                                                 link   price  brs   sqft  \
# 0  https://sfbay.craigslist.org/sfc/apa/d/san-fra...  3850.0  2.0  966.0
# 1  https://sfbay.craigslist.org/sfc/apa/d/san-fra...   900.0  1.0    NaN
# 2  https://sfbay.craigslist.org/sfc/apa/d/san-fra...  4995.0  4.0    NaN
# 3  https://sfbay.craigslist.org/sfc/apa/d/san-fra...  4995.0  4.0    NaN
# 4  https://sfbay.craigslist.org/sfc/apa/d/san-fra...  2800.0  2.0  700.0
#
#                hood bath                                          amenities
# 0       Mission Bay  2Ba        ['condo', 'w/d in unit', 'attached garage']
# 1  portola district  0Ba                                          ['house']
# 2    haight ashbury  2Ba     ['apartment', 'w/d in unit', 'street parking']
# 3    haight ashbury  2Ba     ['apartment', 'w/d in unit', 'street parking']
# 4   USF / panhandle  1Ba  ['apartment', 'laundry in bldg', 'no smoking',...

# %%
df[df["price"]==1]
# Out:
#      date                                              title  \
# 6  Oct  1  ***Private bedroom available in NoPa home. Ren...
#
#                                                 link  price  brs  sqft hood  \
# 6  https://sfbay.craigslist.org/sfc/apa/d/san-fra...    1.0  5.0   NaN  NaN
#
#   bath  amenities
# 6  2Ba  ['house']

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize =(10, 7))

plt.boxplot(df["price"])
plt.show()

# %%
df["price"].sort_values()
# Out:
# 6           1.0
# 2029       75.0
# 1569      100.0
# 1683      150.0
# 2153      199.0
#          ...
# 1933    19000.0
# 1926    22500.0
# 1523    26500.0
# 1541    29000.0
# 1922    29000.0
# Name: price, Length: 3093, dtype: float64

# %%
df = df[df["price"]>700]

# %%
df.head()
# Out:
#      date                                              title  \
# 0  Oct  1  3D Virtual Tour - 2 BR, 2 BA Condo 966 Sq. Ft....
# 1  Oct  1                           Beautiful house for rent
# 2  Oct  1                  4 BEDROOM APARTMENT IN THE HAIGHT
# 3  Oct  1                  4 BEDROOM APARTMENT IN THE HAIGHT
# 4  Oct  1                    ENJOY GOLDEN GATE PARK EVERYDAY
#
#                                                 link   price  brs   sqft  \
# 0  https://sfbay.craigslist.org/sfc/apa/d/san-fra...  3850.0  2.0  966.0
# 1  https://sfbay.craigslist.org/sfc/apa/d/san-fra...   900.0  1.0    NaN
# 2  https://sfbay.craigslist.org/sfc/apa/d/san-fra...  4995.0  4.0    NaN
# 3  https://sfbay.craigslist.org/sfc/apa/d/san-fra...  4995.0  4.0    NaN
# 4  https://sfbay.craigslist.org/sfc/apa/d/san-fra...  2800.0  2.0  700.0
#
#                hood bath                                          amenities
# 0       Mission Bay  2Ba        ['condo', 'w/d in unit', 'attached garage']
# 1  portola district  0Ba                                          ['house']
# 2    haight ashbury  2Ba     ['apartment', 'w/d in unit', 'street parking']
# 3    haight ashbury  2Ba     ['apartment', 'w/d in unit', 'street parking']
# 4   USF / panhandle  1Ba  ['apartment', 'laundry in bldg', 'no smoking',...

# %%
df["price"].min()
# Out:
# 725.0

# %%
df['bath'].unique()
# Out:
# array(['2Ba', '0Ba', '1Ba', '1.5Ba', '2.5Ba', nan, '3Ba', 'splitBa',
#        '3.5Ba', 'sharedBa', '5.5Ba', '4Ba', '4.5Ba'], dtype=object)

# %%
df["Shared_bath"] = df["bath"].str.contains("Shared",case=False, na=False).astype(int)
df["bath_num"] = df["bath"].replace('[^0-9\.]','',regex=True)
df["bath_num"] = pd.to_numeric(df["bath_num"],errors="coerce")
df["bath_num"].head()
# Out:
# 0    2.0
# 1    0.0
# 2    2.0
# 3    2.0
# 4    1.0
# Name: bath_num, dtype: float64

# %%
df["bath_num"].isnull().sum()
# Out:
# 101

# %%
df.describe()
# Out:
#               price          brs          sqft  Shared_bath     bath_num
# count   3085.000000  2471.000000   1461.000000  3085.000000  2984.000000
# mean    3325.981524     1.834885   1202.036277     0.004862     1.295744
# std     1706.216517     0.946041   1316.612823     0.069571     0.531052
# min      725.000000     1.000000    110.000000     0.000000     0.000000
# 25%     2395.000000     1.000000    650.000000     0.000000     1.000000
# 50%     2999.000000     2.000000    902.000000     0.000000     1.000000
# 75%     3943.000000     2.000000   1240.000000     0.000000     1.500000
# max    29000.000000     7.000000  11020.000000     1.000000     5.500000

# %%
if "sqft" in df.columns: #Remueve los datos que son NaN haciendo que no pete el código
    df['price_per_sqft'] = df['price'] / df['sqft']
df.head()
# Out:
#      date                                              title  \
# 0  Oct  1  3D Virtual Tour - 2 BR, 2 BA Condo 966 Sq. Ft....
# 1  Oct  1                           Beautiful house for rent
# 2  Oct  1                  4 BEDROOM APARTMENT IN THE HAIGHT
# 3  Oct  1                  4 BEDROOM APARTMENT IN THE HAIGHT
# 4  Oct  1                    ENJOY GOLDEN GATE PARK EVERYDAY
#
#                                                 link   price  brs   sqft  \
# 0  https://sfbay.craigslist.org/sfc/apa/d/san-fra...  3850.0  2.0  966.0
# 1  https://sfbay.craigslist.org/sfc/apa/d/san-fra...   900.0  1.0    NaN
# 2  https://sfbay.craigslist.org/sfc/apa/d/san-fra...  4995.0  4.0    NaN
# 3  https://sfbay.craigslist.org/sfc/apa/d/san-fra...  4995.0  4.0    NaN
# 4  https://sfbay.craigslist.org/sfc/apa/d/san-fra...  2800.0  2.0  700.0
#
#                hood bath                                          amenities  \
# 0       Mission Bay  2Ba        ['condo', 'w/d in unit', 'attached garage']
# 1  portola district  0Ba                                          ['house']
# 2    haight ashbury  2Ba     ['apartment', 'w/d in unit', 'street parking']
# 3    haight ashbury  2Ba     ['apartment', 'w/d in unit', 'street parking']
# 4   USF / panhandle  1Ba  ['apartment', 'laundry in bldg', 'no smoking',...
#
#    Shared_bath  bath_num  price_per_sqft
# 0            0       2.0        3.985507
# 1            0       0.0             NaN
# 2            0       2.0             NaN
# 3            0       2.0             NaN
# 4            0       1.0        4.000000

# %%
df['hood'].unique()
# Out:
# array(['Mission Bay', 'portola district', 'haight ashbury',
#        'USF / panhandle', 'SOMA / south beach', 'inner richmond',
#        'lower haight', 'mission district', 'Glen Park',
#        'richmond / seacliff', 'Eureka Valley', 'South of Market',
#        'lower nob hill', 'castro / upper market', 'marina / cow hollow',
#        'inner sunset / UCSF', 'hayes valley', 'potrero hill',
#        'sunset / parkside', 'western addition', 'russian hill',
#        'Pacific Heights', 'alamo square / nopa',
#        'north beach / telegraph hill', 'downtown / civic / van ness',
#        'pacific heights', 'bernal heights', 'San Francisco', 'noe valley',
#        'nob hill', 'Nob Hill', 'North Panhandle', 'lower pac hts',
#        'Lower Pacific Heights', 'financial district',
#        'ingleside / SFSU / CCSF', 'Van Ness Corridor / Lower Nob Hill',
#        nan, 'cole valley / ashbury hts', 'bayview', 'tenderloin',
#        'excelsior / outer mission', 'Curtis Park (Heart of Sacramento)',
#        'laurel hts / presidio', 'CA', 'glen park',
#        'South Nob Hill San Francisco', 'west portal / forest hill',
#        'twin peaks / diamond hts', 'Modesto', 'Mariposa', 'Daly City',
#        'Duboce Triangle', 'San Francisco, CA',
#        '1365 McCandless Drive Milpitas, CA', 'Russian Hill', 'NOPA',
#        'Marina', 'Embarcadero / North Waterfront', 'Mission Dolores',
#        'The Castro', 'Hayes Valley', 'Bayview',
#        '2026 Beach St, Concord, CA', 'Golden Gate Heights, San Francisco',
#        'Lawai, Poipu Adjacent',
#        'Duboce Avenue, Pearl Street, Market and Castro', 'SOMA',
#        'Danville', 'San Jose', 'SunnySide',
#        'Lower Haight/Hayes Valley/Duboce Triangle', 'visitacion valley',
#        'North Beach', 'San Francisco North Waterfront', 'Anza Vista',
#        'San Franciso Richmond District', 'san francisco', 'Mountain View',
#        'Tenderloin', 'SAN FRANCISCO', 'Fremont',
#        'North of Panhandle, San Francisco CA', 'South Lake Tahoe',
#        'South Park', 'SOMA/ south beach', 'Westlake',
#        'San Francisco/SunnySide', 'Duboce Park', 'Telegraph Hill',
#        'Hayes valley', 'West Sacramento', 'Downtown San Francisco',
#        'Sunnyvale', 'brisbane', 'Civic Center, Downtown, Van Ness',
#        'On Guerrero Street and 16th Street', 'Nevada City', 'Cupertino',
#        'Rincon Hill', 'Lower Nob Hill', 'South Beach', 'SoMa',
#        'Marina District', 'Ashbury Heights', 'Rincon Hill, San Francisco',
#        'Mission District', 'Austin', 'SF bay area', 'Vallejo',
#        'Yerba Buena', 'Richmond District', 'Cow Hollow'], dtype=object)

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize =(10, 7))

sns.histplot(df["price"], bins=50, log_scale=True) # Custom bin edges
plt.show()

# %%
sns.boxplot(x="brs", y="price",data=df)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x="brs", y="price",data=df, inner=None, color="b",scale="width")
sns.pointplot(x="brs",y="price",data=df,estimator="mean",color="red",markers="o",linestyles="--")
plt.title("Price Distribution by Bedrooms (log scale)")
plt.xlabel("Bedrooms")
plt.ylabel("price")
plt.show()

# %%
sns.barplot(x="hood",y="price",data=df)
plt.xticks(rotation=90) #ALINEA EL NOMBRE DE LOS BARRIOS
plt.show()

# %%
hood_prices = df.groupby("hood")["price"].mean().sort_values(ascending=False).head(25)
sns.barplot(x=hood_prices.index, y=hood_prices.values)
plt.xticks(rotation=45, ha="right")
plt.title("Precio promedio de los barrios")
plt.xlabel("Nombre del barrio")
plt.ylabel("Precio")
plt.show()

# %%
top_p_p_hd = df.sort_values(by="price",ascending=False).head(25)
top_p_p_hd['hood'].unique()
top_p_p_hd['hood'].value_counts()
# Out:
# hood
# SOMA / south beach              8
# pacific heights                 3
# alamo square / nopa             2
# nob hill                        2
# noe valley                      1
# cole valley / ashbury hts       1
# inner sunset / UCSF             1
# richmond / seacliff             1
# Mission Dolores                 1
# north beach / telegraph hill    1
# russian hill                    1
# marina / cow hollow             1
# financial district              1
# potrero hill                    1
# Name: count, dtype: int64

# %%
top_p_p_hd = df.sort_values(by="price_per_sqft",ascending=False).head(25)
top_p_p_hd['hood'].unique()
top_p_p_hd['hood'].value_counts()
# Out:
# hood
# SOMA / south beach            11
# lower nob hill                 4
# ingleside / SFSU / CCSF        2
# nob hill                       2
# inner sunset / UCSF            1
# Rincon Hill, San Francisco     1
# russian hill                   1
# bernal heights                 1
# noe valley                     1
# castro / upper market          1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

num_cols = ["price","brs","bath_num","price_per_sqft","sqft"]
num_cols = [col for col in num_cols if col in df.columns]
corr = df[num_cols].corr()
sns.heatmap(corr,annot=True,cmap="coolwarm")
plt.show()

# %%
############################################
#Modelo, hacer mapas interactivos
