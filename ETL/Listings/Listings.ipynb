# %%
pip install polars
# Out:
# Collecting polars
#   Obtaining dependency information for polars from https://files.pythonhosted.org/packages/d7/c8/226953cda6cf9ae63aa9714d396a9138029e31db3c504c15d6711b618f8f/polars-1.32.3-cp39-abi3-win_amd64.whl.metadata
#   Downloading polars-1.32.3-cp39-abi3-win_amd64.whl.metadata (15 kB)
# Downloading polars-1.32.3-cp39-abi3-win_amd64.whl (38.0 MB)
#    ---------------------------------------- 0.0/38.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.0 MB 262.6 kB/s eta 0:02:25
#    ---------------------------------------- 0.1/38.0 MB 491.5 kB/s eta 0:01:18
#    ---------------------------------------- 0.1/38.0 MB 711.9 kB/s eta 0:00:54
#    ---------------------------------------- 0.3/38.0 MB 1.2 MB/s eta 0:00:31
#     --------------------------------------- 0.6/38.0 MB 1.9 MB/s eta 0:00:20
#     --------------------------------------- 0.8/38.0 MB 2.3 MB/s eta 0:00:17
#    - -------------------------------------- 1.0/38.0 MB 2.5 MB/s eta 0:00:15
#    - -------------------------------------- 1.3/38.0 MB 3.0 MB/s eta 0:00:13
#    -- ------------------------------------- 2.0/38.0 MB 4.2 MB/s eta 0:00:09
#    -- ------------------------------------- 2.2/38.0 MB 4.1 MB/s eta 0:00:09
#    -- ------------------------------------- 2.6/38.0 MB 4.5 MB/s eta 0:00:08
#    --- ------------------------------------ 3.0/38.0 MB 4.7 MB/s eta 0:00:08
#    --- ------------------------------------ 3.1/38.0 MB 4.9 MB/s eta 0:00:08
#    --- ------------------------------------ 3.1/38.0 MB 4.9 MB/s eta 0:00:08
#    --- ------------------------------------ 3.1/38.0 MB 4.9 MB/s eta 0:00:08
#    --- ------------------------------------ 3.3/38.0 MB 4.2 MB/s eta 0:00:09
#    --- ------------------------------------ 3.7/38.0 MB 4.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.2/38.0 MB 4.7 MB/s eta 0:00:08
#    ----- ---------------------------------- 4.8/38.0 MB 5.1 MB/s eta 0:00:07
#    ----- ---------------------------------- 5.2/38.0 MB 5.3 MB/s eta 0:00:07
#    ------ --------------------------------- 5.8/38.0 MB 5.6 MB/s eta 0:00:06
#    ------ --------------------------------- 6.1/38.0 MB 5.5 MB/s eta 0:00:06
#    ------- -------------------------------- 7.0/38.0 MB 6.2 MB/s eta 0:00:05
#    ------- -------------------------------- 7.4/38.0 MB 6.4 MB/s eta 0:00:05
#    -------- ------------------------------- 7.7/38.0 MB 6.3 MB/s eta 0:00:05
#    -------- ------------------------------- 8.0/38.0 MB 6.4 MB/s eta 0:00:05
#    -------- ------------------------------- 8.5/38.0 MB 6.7 MB/s eta 0:00:05
#    --------- ------------------------------ 9.0/38.0 MB 6.6 MB/s eta 0:00:05
#    --------- ------------------------------ 9.0/38.0 MB 6.6 MB/s eta 0:00:05
#    --------- ------------------------------ 9.5/38.0 MB 6.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.0/38.0 MB 6.6 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.0/38.0 MB 6.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.4/38.0 MB 7.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 10.6/38.0 MB 7.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 11.1/38.0 MB 8.0 MB/s eta 0:00:04
#    ------------ --------------------------- 11.5/38.0 MB 8.0 MB/s eta 0:00:04
#    ------------ --------------------------- 11.7/38.0 MB 8.0 MB/s eta 0:00:04
#    ------------ --------------------------- 12.2/38.0 MB 7.7 MB/s eta 0:00:04
#    ------------- -------------------------- 12.9/38.0 MB 8.1 MB/s eta 0:00:04
#    ------------- -------------------------- 13.3/38.0 MB 8.1 MB/s eta 0:00:04
#    ------------- -------------------------- 13.3/38.0 MB 8.1 MB/s eta 0:00:04
#    -------------- ------------------------- 13.9/38.0 MB 8.8 MB/s eta 0:00:03
#    --------------- ------------------------ 14.3/38.0 MB 8.8 MB/s eta 0:00:03
#    --------------- ------------------------ 14.3/38.0 MB 8.8 MB/s eta 0:00:03
#    --------------- ------------------------ 14.8/38.0 MB 8.5 MB/s eta 0:00:03
#    --------------- ------------------------ 15.1/38.0 MB 8.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 15.2/38.0 MB 8.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 15.7/38.0 MB 8.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 16.5/38.0 MB 8.3 MB/s eta 0:00:03
#    ----------------- ---------------------- 16.8/38.0 MB 8.2 MB/s eta 0:00:03
#    ------------------ --------------------- 17.4/38.0 MB 8.1 MB/s eta 0:00:03
#    ------------------ --------------------- 18.0/38.0 MB 8.2 MB/s eta 0:00:03
#    ------------------- -------------------- 18.6/38.0 MB 8.4 MB/s eta 0:00:03
#    -------------------- ------------------- 19.4/38.0 MB 9.2 MB/s eta 0:00:03
#    --------------------- ------------------ 20.5/38.0 MB 10.1 MB/s eta 0:00:02
#    --------------------- ------------------ 20.8/38.0 MB 9.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.3/38.0 MB 9.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.2/38.0 MB 10.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.2/38.0 MB 10.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.5/38.0 MB 10.2 MB/s eta 0:00:02
#    ------------------------ --------------- 23.2/38.0 MB 10.2 MB/s eta 0:00:02
#    ------------------------- -------------- 23.8/38.0 MB 10.7 MB/s eta 0:00:02
#    ------------------------- -------------- 24.2/38.0 MB 10.9 MB/s eta 0:00:02
#    -------------------------- ------------- 25.0/38.0 MB 11.7 MB/s eta 0:00:02
#    -------------------------- ------------- 25.5/38.0 MB 12.1 MB/s eta 0:00:02
#    --------------------------- ------------ 26.2/38.0 MB 12.1 MB/s eta 0:00:01
#    --------------------------- ------------ 26.5/38.0 MB 12.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.1/38.0 MB 12.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.5/38.0 MB 12.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.0/38.0 MB 12.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.4/38.0 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 29.4/38.0 MB 11.7 MB/s eta 0:00:01
#    ------------------------------- -------- 30.0/38.0 MB 11.7 MB/s eta 0:00:01
#    -------------------------------- ------- 30.8/38.0 MB 11.7 MB/s eta 0:00:01
#    --------------------------------- ------ 31.6/38.0 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 32.5/38.0 MB 13.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 33.5/38.0 MB 13.9 MB/s eta 0:00:01
#    ------------------------------------ --- 34.4/38.0 MB 14.9 MB/s eta 0:00:01
#    ------------------------------------ --- 35.2/38.0 MB 13.9 MB/s eta 0:00:01
#    ------------------------------------- -- 35.8/38.0 MB 14.2 MB/s eta 0:00:01
#    -------------------------------------- - 36.4/38.0 MB 14.9 MB/s eta 0:00:01
#    -------------------------------------- - 36.8/38.0 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  37.8/38.0 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  37.8/38.0 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  37.8/38.0 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.0 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.0 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.0 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.0 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.0 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.0 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.0 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.0 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------- 38.0/38.0 MB 9.0 MB/s eta 0:00:00
# Installing collected packages: polars
# Successfully installed polars-1.32.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('listings_mexico.csv')

# %%
df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  2.606700e+04  2.606700e+04  2.606700e+04         26062.000000
# mean   6.041349e+17  2.025032e+13  2.288527e+08            25.900852
# std    5.265872e+17  7.906402e+00  1.954205e+08            86.765206
# min    3.579700e+04  2.025032e+13  7.365000e+03             1.000000
# 25%    4.164114e+07  2.025032e+13  5.259008e+07             1.000000
# 50%    7.398440e+17  2.025032e+13  1.648988e+08             4.000000
# 75%    1.090846e+18  2.025032e+13  3.991943e+08            14.000000
# max    1.379814e+18  2.025032e+13  6.847160e+08           886.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed      latitude  \
# count               26062.000000                           0.0  26067.000000
# mean                   35.072826                           NaN     19.405242
# std                   123.984298                           NaN      0.042514
# min                     1.000000                           NaN     19.095762
# 25%                     2.000000                           NaN     19.391840
# 50%                     5.000000                           NaN     19.415150
# 75%                    17.000000                           NaN     19.431940
# max                  1049.000000                           NaN     19.561010
#
#           longitude  accommodates     bathrooms  ...  review_scores_checkin  \
# count  26067.000000  26067.000000  22062.000000  ...           22805.000000
# mean     -99.166046      3.346760      1.451432  ...               4.837276
# std        0.033489      2.359036      1.030367  ...               0.326791
# min      -99.339630      1.000000      0.000000  ...               1.000000
# 25%      -99.178873      2.000000      1.000000  ...               4.820000
# 50%      -99.167399      2.000000      1.000000  ...               4.920000
# 75%      -99.154379      4.000000      2.000000  ...               5.000000
# max      -98.963360     16.000000     49.000000  ...               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                 22805.000000            22805.000000
# mean                      4.823005                4.840322
# std                       0.360575                0.298210
# min                       1.000000                1.000000
# 25%                       4.800000                4.800000
# 50%                       4.920000                4.920000
# 75%                       5.000000                5.000000
# max                       5.000000                5.000000
#
#        review_scores_value  license  calculated_host_listings_count  \
# count         22805.000000      0.0                    26067.000000
# mean              4.713932      NaN                       15.491886
# std               0.394899      NaN                       36.230505
# min               1.000000      NaN                        1.000000
# 25%               4.670000      NaN                        1.000000
# 50%               4.800000      NaN                        3.000000
# 75%               4.910000      NaN                       11.000000
# max               5.000000      NaN                      242.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 26067.000000
# mean                                     12.622626
# std                                      35.795452
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       6.000000
# max                                     242.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  26067.000000
# mean                                       2.690068
# std                                        7.340992
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        2.000000
# max                                       65.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                 26067.000000       22806.000000
# mean                                      0.141904           1.803389
# std                                       1.566747           2.032845
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.450000
# 50%                                       0.000000           1.230000
# 75%                                       0.000000           2.560000
# max                                      28.000000          61.050000
#
# [8 rows x 45 columns]

# %%
len(df)
# Out:
# 26067

# %%
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  35797  https://www.airbnb.com/rooms/35797  20250319150644   2025-03-21
# 1  44616  https://www.airbnb.com/rooms/44616  20250319150644   2025-03-20
# 2  56074  https://www.airbnb.com/rooms/56074  20250319150644   2025-03-20
# 3  67703  https://www.airbnb.com/rooms/67703  20250319150644   2025-03-20
# 4  70644  https://www.airbnb.com/rooms/70644  20250319150644   2025-03-22
#
#             source                                              name  \
# 0      city scrape                                       Villa Dante
# 1  previous scrape                                      Condesa Haus
# 2      city scrape              Great space in historical San Rafael
# 3  previous scrape                 2 bedroom apt. deco bldg, Condesa
# 4      city scrape  Beautiful light Studio Coyoacan- full equipped !
#
#                                          description  \
# 0  Dentro de Villa un estudio de arte con futon, ...
# 1  A new concept of hosting in mexico through a b...
# 2  This great apartment is located in one of the ...
# 3  Comfortably furnished, sunny, 2 bedroom apt., ...
# 4  COYOACAN designer studio quiet & safe! well eq...
#
#                                neighborhood_overview  \
# 0  Santa Fe Shopping Mall, Interlomas Park and th...
# 1                                                NaN
# 2  Very traditional neighborhood with all service...
# 3                                                NaN
# 4  Coyoacan is a beautiful neighborhood famous fo...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/f395ab78-1185...   153786  ...
# 1  https://a0.muscache.com/pictures/251410/ec75fe...   196253  ...
# 2  https://a0.muscache.com/pictures/3005118/60dac...   265650  ...
# 3  https://a0.muscache.com/pictures/3281720/6f078...   334451  ...
# 4  https://a0.muscache.com/pictures/f397d2da-d045...   212109  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                         NaN                    NaN                 NaN
# 1                        4.78                   4.98                4.47
# 2                        4.94                   4.76                4.79
# 3                        4.92                   4.98                4.92
# 4                        4.98                   4.96                4.92
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              1
# 1     NaN                f                              9
# 2     NaN                f                              1
# 3     NaN                f                              2
# 4     NaN                f                              3
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           4
# 2                                           1
# 3                                           2
# 4                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            2
# 2                                            0
# 3                                            0
# 4                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0               NaN
# 1                                           0              0.40
# 2                                           0              0.49
# 3                                           0              0.31
# 4                                           0              0.83
#
# [5 rows x 79 columns]

# %%
df
# Out:
#                         id                                       listing_url  \
# 0                    35797                https://www.airbnb.com/rooms/35797
# 1                    44616                https://www.airbnb.com/rooms/44616
# 2                    56074                https://www.airbnb.com/rooms/56074
# 3                    67703                https://www.airbnb.com/rooms/67703
# 4                    70644                https://www.airbnb.com/rooms/70644
# ...                    ...                                               ...
# 26062  1379327529227113949  https://www.airbnb.com/rooms/1379327529227113949
# 26063  1379338090263773362  https://www.airbnb.com/rooms/1379338090263773362
# 26064  1379781424660291699  https://www.airbnb.com/rooms/1379781424660291699
# 26065  1379807014531191212  https://www.airbnb.com/rooms/1379807014531191212
# 26066  1379814270520534429  https://www.airbnb.com/rooms/1379814270520534429
#
#             scrape_id last_scraped           source  \
# 0      20250319150644   2025-03-21      city scrape
# 1      20250319150644   2025-03-20  previous scrape
# 2      20250319150644   2025-03-20      city scrape
# 3      20250319150644   2025-03-20  previous scrape
# 4      20250319150644   2025-03-22      city scrape
# ...               ...          ...              ...
# 26062  20250319150644   2025-03-22      city scrape
# 26063  20250319150644   2025-03-20      city scrape
# 26064  20250319150644   2025-03-20      city scrape
# 26065  20250319150644   2025-03-22      city scrape
# 26066  20250319150644   2025-03-20      city scrape
#
#                                                     name  \
# 0                                            Villa Dante
# 1                                           Condesa Haus
# 2                   Great space in historical San Rafael
# 3                      2 bedroom apt. deco bldg, Condesa
# 4       Beautiful light Studio Coyoacan- full equipped !
# ...                                                  ...
# 26062                   Cama en Dorm mixto de 4 personas
# 26063  loft #307 excelente ubicación ideal para descanso
# 26064                            Cozy room in Roma Norte
# 26065   Stylish suite w private terrace close to Polanco
# 26066                     Depto. en el corazón de Roma N
#
#                                              description  \
# 0      Dentro de Villa un estudio de arte con futon, ...
# 1      A new concept of hosting in mexico through a b...
# 2      This great apartment is located in one of the ...
# 3      Comfortably furnished, sunny, 2 bedroom apt., ...
# 4      COYOACAN designer studio quiet & safe! well eq...
# ...                                                  ...
# 26062  Casa Pepe is a hotel with a hostel vocation th...
# 26063  Very nice room for 2 people (children under 12...
# 26064  Located in the Colonia Roma Norte (Roma-Condes...
# 26065  Tucked away in the lively neighborhood of Anzu...
# 26066  Apartment with 2 bedrooms, 2 bathrooms, 2 doub...
#
#                                    neighborhood_overview  \
# 0      Santa Fe Shopping Mall, Interlomas Park and th...
# 1                                                    NaN
# 2      Very traditional neighborhood with all service...
# 3                                                    NaN
# 4      Coyoacan is a beautiful neighborhood famous fo...
# ...                                                  ...
# 26062                                                NaN
# 26063                                                NaN
# 26064                                                NaN
# 26065  Anzures is situated in the heart of Mexico Cit...
# 26066                                                NaN
#
#                                              picture_url    host_id  ...  \
# 0      https://a0.muscache.com/pictures/f395ab78-1185...     153786  ...
# 1      https://a0.muscache.com/pictures/251410/ec75fe...     196253  ...
# 2      https://a0.muscache.com/pictures/3005118/60dac...     265650  ...
# 3      https://a0.muscache.com/pictures/3281720/6f078...     334451  ...
# 4      https://a0.muscache.com/pictures/f397d2da-d045...     212109  ...
# ...                                                  ...        ...  ...
# 26062  https://a0.muscache.com/pictures/miso/Hosting-...  261044377  ...
# 26063  https://a0.muscache.com/pictures/hosting/Hosti...  175442219  ...
# 26064  https://a0.muscache.com/pictures/miso/Hosting-...   34664434  ...
# 26065  https://a0.muscache.com/pictures/prohost-api/H...  515054008  ...
# 26066  https://a0.muscache.com/pictures/miso/Hosting-...  189134785  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                             NaN                    NaN                 NaN
# 1                            4.78                   4.98                4.47
# 2                            4.94                   4.76                4.79
# 3                            4.92                   4.98                4.92
# 4                            4.98                   4.96                4.92
# ...                           ...                    ...                 ...
# 26062                         NaN                    NaN                 NaN
# 26063                         NaN                    NaN                 NaN
# 26064                         NaN                    NaN                 NaN
# 26065                         NaN                    NaN                 NaN
# 26066                         NaN                    NaN                 NaN
#
#       license instant_bookable calculated_host_listings_count  \
# 0         NaN                f                              1
# 1         NaN                f                              9
# 2         NaN                f                              1
# 3         NaN                f                              2
# 4         NaN                f                              3
# ...       ...              ...                            ...
# 26062     NaN                t                              8
# 26063     NaN                f                              1
# 26064     NaN                f                              2
# 26065     NaN                t                             32
# 26066     NaN                f                              1
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               1
# 1                                               4
# 2                                               1
# 3                                               2
# 4                                               2
# ...                                           ...
# 26062                                           0
# 26063                                           0
# 26064                                           0
# 26065                                          32
# 26066                                           1
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                2
# 2                                                0
# 3                                                0
# 4                                                1
# ...                                            ...
# 26062                                            4
# 26063                                            1
# 26064                                            2
# 26065                                            0
# 26066                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0               NaN
# 1                                               0              0.40
# 2                                               0              0.49
# 3                                               0              0.31
# 4                                               0              0.83
# ...                                           ...               ...
# 26062                                           4               NaN
# 26063                                           0               NaN
# 26064                                           0               NaN
# 26065                                           0               NaN
# 26066                                           0               NaN
#
# [26067 rows x 79 columns]

# %%
df[['price']].isnull().sum()
# Out:
# price    3999
# dtype: int64

# %%
df = df.dropna(subset=['price'])

# %%
df[['price']].isnull().sum()
# Out:
# price    0
# dtype: int64

# %%
df['price'] = df['price'].str.replace('$', '')
df['price'] = df['price'].str.replace(',', '')
df['price'] = df['price'].astype(float)
# Out:
# C:\Users\luisn\AppData\Local\Temp\ipykernel_3436\3445222675.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].str.replace('$', '')
# C:\Users\luisn\AppData\Local\Temp\ipykernel_3436\3445222675.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].str.replace(',', '')
# C:\Users\luisn\AppData\Local\Temp\ipykernel_3436\3445222675.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].astype(float)

# %%
df['price'].mean()
# Out:
# 1665.005981511691

# %%
df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    14843
# Private room        6995
# Shared room          169
# Hotel room            61
# Name: count, dtype: int64

# %%
df['host_name'].value_counts()
# Out:
# host_name
# Alejandra       305
# Alejandro       244
# Juan            241
# Blueground      225
# Raul            225
#                ...
# Elsa Eugenia      1
# Jose P.           1
# Juan Alberto      1
# Neal              1
# Kath              1
# Name: count, Length: 3602, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'availability_eoy',
#        'number_of_reviews_ly', 'estimated_occupancy_l365d',
#        'estimated_revenue_l365d', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
df['host_neighbourhood'].value_counts()
# Out:
# host_neighbourhood
# Polanco                                        1487
# Roma Norte                                     1002
# Condesa                                         645
# Chapultepec Morales                             605
# Centro Histórico de la Ciudad de México         460
#                                                ...
# Tlatilco                                          1
# Hell's Kitchen                                    1
# reforma social                                    1
# Xoco, Benito Juárez - Muy cerca de Coyoacán       1
# Cerro Norte                                       1
# Name: count, Length: 891, dtype: int64

# %%
df['host_id'].value_counts()
# Out:
# host_id
# 498701635    225
# 10764020     178
# 16148871     159
# 333035396    144
# 245618000    105
#             ...
# 415363200      1
# 10038590       1
# 112249312      1
# 177880021      1
# 189134785      1
# Name: count, Length: 9802, dtype: int64

# %%
df['host_name'].value_counts()
# Out:
# host_name
# Alejandra       305
# Alejandro       244
# Juan            241
# Blueground      225
# Raul            225
#                ...
# Elsa Eugenia      1
# Jose P.           1
# Juan Alberto      1
# Neal              1
# Kath              1
# Name: count, Length: 3602, dtype: int64

# %%
host_counts = df.groupby(['host_id', 'host_name']).size().sort_values(ascending=False)
print(host_counts)
# Out:
# host_id    host_name
# 498701635  Blueground            225
# 10764020   Mr. W                 178
# 16148871   Juan                  159
# 333035396  Clau                  144
# 245618000  Alejandra             105
#                                 ...
# 108892555  Magali Del Socorro      1
# 108732385  Patti                   1
# 108731535  Erick                   1
# 108631341  Charlotte               1
# 684715954  Dafne Daniela           1
# Length: 9800, dtype: int64
