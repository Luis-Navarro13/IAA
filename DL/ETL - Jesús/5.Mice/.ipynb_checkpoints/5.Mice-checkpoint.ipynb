# %%
#Notebook 5.Mice
import seaborn as sns
import pandas as pd
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
print(titanic.isnull().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data = titanic[['age','fare','pclass','sex']]
data = pd.get_dummies(data, drop_first=True)

# %%
data.head()
# Out:
#     age     fare  pclass  sex_male
# 0  22.0   7.2500       3      True
# 1  38.0  71.2833       1     False
# 2  26.0   7.9250       3     False
# 3  35.0  53.1000       1     False
# 4  35.0   8.0500       3      True

# %%
imputer = IterativeImputer(max_iter=10, random_state=0)

# %%
data_imputed = pd.DataFrame(imputer.fit_transform(data), columns=data.columns)

# %%
print("Datos originales:\n",data.head(6))
print("\nDatos imputados:\n",data_imputed.head(6))
# Out:
# Datos originales:
#      age     fare  pclass  sex_male
# 0  22.0   7.2500       3      True
# 1  38.0  71.2833       1     False
# 2  26.0   7.9250       3     False
# 3  35.0  53.1000       1     False
# 4  35.0   8.0500       3      True
# 5   NaN   8.4583       3      True
#
# Datos imputados:
#           age     fare  pclass  sex_male
# 0  22.000000   7.2500     3.0       1.0
# 1  38.000000  71.2833     1.0       0.0
# 2  26.000000   7.9250     3.0       0.0
# 3  35.000000  53.1000     1.0       0.0
# 4  35.000000   8.0500     3.0       1.0
# 5  26.082704   8.4583     3.0       1.0

# %%
life_expectancy = pd.read_csv('Life_Expectancy_Data.csv')

# %%
life_expectancy.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
life_expectancy  = life_expectancy.drop(['Country','Status'], axis=1)

# %%
print(life_expectancy.isnull().sum())
# Out:
# Year                                 0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
imputer = IterativeImputer(max_iter=10, random_state=0)

# %%
life_expectancy_imputed = pd.DataFrame(imputer.fit_transform(life_expectancy), columns=life_expectancy.columns)

# %%
print("Datos originales:\n",life_expectancy.head(6))
print("\nDatos imputados:\n",life_expectancy_imputed.head(6))
# Out:
# Datos originales:
#     Year  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0  2015              65.0            263.0             62     0.01
# 1  2014              59.9            271.0             64     0.01
# 2  2013              59.9            268.0             66     0.01
# 3  2012              59.5            272.0             69     0.01
# 4  2011              59.2            275.0             71     0.01
# 5  2010              58.8            279.0             74     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0      1154   19.1                  83
# 1               73.523582         62.0       492   18.6                  86
# 2               73.219243         64.0       430   18.1                  89
# 3               78.184215         67.0      2787   17.6                  93
# 4                7.097109         68.0      3013   17.2                  97
# ...

# %%
Planets seaborn
